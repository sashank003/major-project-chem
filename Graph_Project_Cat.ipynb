# %% [markdown]
# <a href="https://colab.research.google.com/github/sashank003/major-project-chem/blob/ML/Graph_Project_Cat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-42ae0891-f004-4e83-92eb-3cda304a0bd5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42ae0891-f004-4e83-92eb-3cda304a0bd5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving MQ_test_488_Y_ok.csv to MQ_test_488_Y_ok.csv
# ...

# %%
files.upload()
# Out:
#      <input type="file" id="files-d45413dd-1a2a-4641-bc5e-84dfc70c8664" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d45413dd-1a2a-4641-bc5e-84dfc70c8664">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pred_cat_lr_0.01.csv to pred_cat_lr_0.01.csv
# ...

# %%
test = pd.read_csv("/content/MQ_test_488_Y_ok.csv")
pred = pd.read_csv("/content/pred_cat_lr_0.01.csv")

# %%
column = test.columns.to_list()

# %%
test.shape
# Out:
# (488, 41)

# %%
pred.shape
# Out:
# (488, 42)

# %%
pred.drop(["Unnamed: 0"], inplace = True, axis = 1)

# %%
test
# Out:
#           380       390       400  ...       760       770       780
# 0    0.022603  0.024319  0.032150  ...  0.021966  0.017786  0.011003
# 1    0.232916  0.190780  0.109389  ...  0.839536  0.843518  0.829029
# 2    0.157208  0.132077  0.080254  ...  0.718720  0.705801  0.702384
# 3    0.128306  0.092704  0.065420  ...  0.625823  0.616591  0.573795
# 4    0.042030  0.046262  0.051218  ...  0.156525  0.149148  0.147667
# ..        ...       ...       ...  ...       ...       ...       ...
# 483  0.678618  0.666170  0.627844  ...  0.720301  0.741506  0.769483
# 484  0.656487  0.651785  0.612093  ...  0.702085  0.722167  0.722909
# 485  0.656487  0.655607  0.612093  ...  0.717452  0.741506  0.748845
# 486  0.656487  0.655607  0.612093  ...  0.717452  0.741506  0.739995
# 487  0.656487  0.651785  0.612093  ...  0.702085  0.722167  0.722909
#
# [488 rows x 41 columns]

# %%
pred
# Out:
#           380       390       400  ...       760       770       780
# 0    0.021576  0.023843  0.032630  ...  0.019807  0.016301  0.012151
# 1    0.233356  0.185051  0.103870  ...  0.816003  0.810588  0.807472
# 2    0.149767  0.122988  0.074696  ...  0.704052  0.703756  0.686440
# 3    0.147332  0.122189  0.075259  ...  0.678839  0.672472  0.649061
# 4    0.041721  0.045115  0.049047  ...  0.191359  0.195070  0.179780
# ..        ...       ...       ...  ...       ...       ...       ...
# 483  0.669779  0.658511  0.622742  ...  0.745674  0.771014  0.772418
# 484  0.625410  0.625365  0.587282  ...  0.700559  0.719494  0.713176
# 485  0.663439  0.657817  0.618843  ...  0.713686  0.735433  0.752537
# 486  0.654265  0.653111  0.611079  ...  0.706205  0.728521  0.738090
# 487  0.650607  0.648648  0.606239  ...  0.702075  0.722823  0.721792
#
# [488 rows x 41 columns]

# %%
x = column

# %%
y = test.loc[0].values
yp = pred.loc[0].values

# %%
y5 = test.loc[5].values
yp5 = pred.loc[5].values

# %%
y6 = test.loc[6].values
yp6 = pred.loc[6].values

# %%
y55 = test.loc[2].values
yp55 = pred.loc[2].values

# %%
fig = plt.figure(figsize=(15,10))
plt.xlabel("Wavelength")
plt.ylabel("Reflectance")
plt.plot(x, y5, label = "Actual Output / Reflectance")
plt.plot(x, yp5, label = "Predicted Output / Reflectance")
plt.xticks(rotation = 90)
plt.legend(loc='best')
plt.show()
fig.savefig("five")

# %%
fig = plt.figure(figsize=(15,10))
plt.xlabel("Wavelength")
plt.ylabel("Reflectance")
plt.plot(x, y6, label = "Actual Output / Reflectance")
plt.plot(x, yp6, label = "Predicted Output / Reflectance")
plt.xticks(rotation = 90)
plt.legend(loc='best')
plt.show()
fig.savefig("six")

# %%
fig = plt.figure(figsize=(15,10))
plt.xlabel("Wavelength")
plt.ylabel("Reflectance")
plt.plot(x, y, label = "Actual Output / Reflectance")
plt.plot(x, yp, label = "Predicted Output / Reflectance")
plt.xticks(rotation = 90)
plt.legend(loc='best')
plt.show()
fig.savefig("zero")

# %%
fig = plt.figure(figsize=(15,10))
plt.xlabel("Wavelength")
plt.ylabel("Reflectance")
plt.plot(x, y55, label = "Actual Output / Reflectance")
plt.plot(x, yp55, label = "Predicted Output / Reflectance")
plt.xticks(rotation = 90)
plt.legend(loc='best')
plt.show()
fig.savefig("two")
